# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import cv2
import matplotlib.pylab as plt
import pandas as pd
# %matplotlib inline
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Libraries

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# ## Load image's path and mask's path

# %%
import glob
images_path = glob.glob('/content/drive/MyDrive/AllMassFile/*.png')
mask_path = glob.glob('/content/drive/MyDrive/mask&images/*.png')

image_normal = glob.glob('/content/drive/MyDrive/normal/*.png')
mask_normal = glob.glob('/content/drive/MyDrive/normalmask/*.png')

# %%
MASS_PATIENT_ID = ['53586896', '22580192', '22614236', '22580098', '24055445', '30011674', 
                   '20586934', '22670465', '24055502', '22670673', '20587612', '22614568', 
                   '20587902', '22614522', '50995789', '24055464', '20588216', '51049053', 
                   '53582656', '20588562', '27829188', '22614431', '22580341', '22613822', 
                   '24065584', '50997515', '51049107', '22580367', '22580244', '50996352', 
                   '22670147', '22580732', '50999008', '24065707', '22614127', '20588334', 
                   '20588536', '24065530', '22670324', '20586908', '30011507', '27829134', 
                   '53581406', '50998981', '20586986', '22678787', '50997461', '53580804', 
                   '22579730', '22670094', '53580858', '53586869', '50995762', '24065251', 
                   '20587810', '53581460', '22670855', '22580706', '30011553', '22670809', 
                   '22580419', '24055355', '53587014', '50994408', '22614379', '22670278', 
                   '24065289', '22614074', '24055274', '22670511', '50994354', '20587928', 
                   '22580393', '22580654', '20588046', '50994273', '20587758', '24065761', 
                   '22427751', '20587664', '50999432', '22580680', '22580038', '53587663', 
                   '20588308', '20588680', '30011727', '22678833', '22427705', '22614266', 
                   '22613650', '50999459', '24055483', '22678694', '20587994', '22678646', 
                   '53582683', '20586960', '51048765', '22670620', '22613770', '22427840', 
                   '20588190', '53586960', '50996406', '22613702', '51048738']

# %%
import os
file_names_mask =[]
for filename in os.listdir('/content/drive/MyDrive/mask&images'):
    if filename.endswith(".png"):
          if filename[:8] in MASS_PATIENT_ID:
              file_names_mask.append('/content/drive/MyDrive/mask&images/'+filename)

# %%
len(file_names_mask)
# Out:
# 107

# %%
file_names_mask.sort()

# %%
file_names_mass =[]
for filename in os.listdir('/content/drive/MyDrive/AllMassFile'):
    if filename.endswith(".png"):
          if filename[:8] in MASS_PATIENT_ID:
              file_names_mass.append('/content/drive/MyDrive/AllMassFile/'+filename)

# %%
len(file_names_mass)
# Out:
# 107

# %%
file_names_mass.sort()

# %%
len(image_normal),len(mask_normal)
# Out:
# (107, 107)

# %%
image_normal.sort(),mask_normal.sort()
# Out:
# (None, None)

# %% [markdown]
# ## Data Visualization

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=file_names_mass[i]
    msk_path=file_names_mask[i]
    img=cv2.imread(img_path)
    img=cv2.resize(img,(256,256))
    # img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    msk=cv2.resize(msk,(256,256))
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=image_normal[i]
    msk_path=mask_normal[i]
    img=cv2.imread(img_path)
    img=cv2.resize(img,(256,256))
    # img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    msk=cv2.resize(msk,(256,256))
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %% [markdown]
# ## Create data frame and split data on train set, validation set and test set

# %%
files = [*file_names_mass, *image_normal] 
mask = [*file_names_mask, *mask_normal]

# %%
df = pd.DataFrame(data={"filename": files, 'mask' : mask})
shuffled = df.sample(frac=1)

df_train, df_test = train_test_split(shuffled,test_size = 0.1)
df_train, df_val = train_test_split(df_train,test_size = 0.2)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (153, 2)
# (39, 2)
# (22, 2)

# %%
shuffled

# %% [markdown]
# ## Data genertator, data augmentation and adjust data

# %% [markdown]
# The steps_per_epoch parameter is key because an ImageDataGenerator can provide an infinite number of versions of each image. In this example, the batch_size parameter passed to flow tells the generator to create 10 images in each batch (each call to next). Dividing the number of images by the image batch size to calculate steps_per_epoch ensures that in each training epoch, the model is provided with one transformed version of each image in the dataset.

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %% [markdown]
# ## Define loss function and metrics

# %%
smooth=100

def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def jac_distance(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)

    return - iou(y_true, y_pred)

# %% [markdown]
# ## Define Unet

# %%
def unet(input_size=(256,256,3)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(64, (3, 3), padding='same')(inputs)
    bn1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, (3, 3), padding='same')(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation('relu')(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)

    conv2 = Conv2D(128, (3, 3), padding='same')(pool1)
    bn2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, (3, 3), padding='same')(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation('relu')(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)

    conv3 = Conv2D(256, (3, 3), padding='same')(pool2)
    bn3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, (3, 3), padding='same')(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation('relu')(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)

    conv4 = Conv2D(512, (3, 3), padding='same')(pool3)
    bn4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, (3, 3), padding='same')(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation('relu')(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(1024, (3, 3), padding='same')(pool4)
    bn5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, (3, 3), padding='same')(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation('relu')(bn5)

    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bn5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), padding='same')(up6)
    bn6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, (3, 3), padding='same')(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation('relu')(bn6)

    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), padding='same')(up7)
    bn7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, (3, 3), padding='same')(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation('relu')(bn7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), padding='same')(up8)
    bn8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, (3, 3), padding='same')(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation('relu')(bn8)

    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), padding='same')(up9)
    bn9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, (3, 3), padding='same')(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation('relu')(bn9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
model = unet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d_1[0][0]']
#  alization)                     )
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['conv2d_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_1[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  activation_8 (Activation)      (None, 16, 16, 1024  0           ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 16, 16, 1024  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 512)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_11 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  524544     ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  activation_12 (Activation)     (None, 64, 64, 256)  0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_13[0][0]']
#  rmalization)
#
#  activation_13 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  activation_14 (Activation)     (None, 128, 128, 12  0           ['conv2d_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 12  512        ['conv2d_15[0][0]']
#  rmalization)                   8)
#
#  activation_15 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_7[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 256, 256, 64  0           ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 64  256        ['conv2d_17[0][0]']
#  rmalization)                   )
#
#  activation_17 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,043,521
# Trainable params: 31,037,633
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
EPOCHS = 300
BATCH_SIZE = 32
learning_rate = 1e-4

# %%
im_height = 256
im_width = 256

# %%
train_generator_args = dict(rotation_range=0.5,
                            width_shift_range=0.2,
                            height_shift_range=0.2,
                            shear_range=0.05,
                            zoom_range=0.1,
                            horizontal_flip=True,
                            vertical_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(im_height, im_width))
    
test_gener = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
    
model = unet(input_size=(im_height, im_width, 3))



decay_rate = learning_rate / EPOCHS
# opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=decay_rate, amsgrad=False)
model.compile(optimizer='adam', loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

callbacks = [ModelCheckpoint('/content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5', verbose=1, save_best_only=True)]

history = model.fit(train_gen,
                    steps_per_epoch=11, 
                    epochs=EPOCHS, 
                    callbacks=callbacks,
                    validation_data = test_gener,
                    validation_steps=11)
# Out:
# Found 153 validated image filenames.
# Found 153 validated image filenames.
# Epoch 1/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0242 - binary_accuracy: 0.6751 - iou: 0.0124 - dice_coef: 0.0242Found 39 validated image filenames.
# Found 39 validated image filenames.
#
# Epoch 1: val_loss improved from inf to -0.01444, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 186s 15s/step - loss: -0.0242 - binary_accuracy: 0.6751 - iou: 0.0124 - dice_coef: 0.0242 - val_loss: -0.0144 - val_binary_accuracy: 0.0318 - val_iou: 0.0073 - val_dice_coef: 0.0144
# Epoch 2/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0286 - binary_accuracy: 0.7981 - iou: 0.0147 - dice_coef: 0.0287
# Epoch 2: val_loss improved from -0.01444 to -0.01473, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 89s 9s/step - loss: -0.0286 - binary_accuracy: 0.7981 - iou: 0.0147 - dice_coef: 0.0287 - val_loss: -0.0147 - val_binary_accuracy: 0.0506 - val_iou: 0.0074 - val_dice_coef: 0.0145
# Epoch 3/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0313 - binary_accuracy: 0.8536 - iou: 0.0160 - dice_coef: 0.0311
# Epoch 3: val_loss improved from -0.01473 to -0.01496, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 91s 9s/step - loss: -0.0313 - binary_accuracy: 0.8536 - iou: 0.0160 - dice_coef: 0.0311 - val_loss: -0.0150 - val_binary_accuracy: 0.0611 - val_iou: 0.0068 - val_dice_coef: 0.0132
# Epoch 4/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0373 - binary_accuracy: 0.8837 - iou: 0.0194 - dice_coef: 0.0378
# Epoch 4: val_loss did not improve from -0.01496
# 11/11 [==============================] - 87s 9s/step - loss: -0.0373 - binary_accuracy: 0.8837 - iou: 0.0194 - dice_coef: 0.0378 - val_loss: -0.0127 - val_binary_accuracy: 0.4447 - val_iou: 0.0058 - val_dice_coef: 0.0113
# Epoch 5/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0487 - binary_accuracy: 0.9207 - iou: 0.0245 - dice_coef: 0.0474
# Epoch 5: val_loss did not improve from -0.01496
# 11/11 [==============================] - 87s 9s/step - loss: -0.0487 - binary_accuracy: 0.9207 - iou: 0.0245 - dice_coef: 0.0474 - val_loss: -0.0106 - val_binary_accuracy: 0.0461 - val_iou: 0.0052 - val_dice_coef: 0.0102
# Epoch 6/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0575 - binary_accuracy: 0.9520 - iou: 0.0301 - dice_coef: 0.0574
# Epoch 6: val_loss did not improve from -0.01496
# 11/11 [==============================] - 86s 8s/step - loss: -0.0575 - binary_accuracy: 0.9520 - iou: 0.0301 - dice_coef: 0.0574 - val_loss: -0.0103 - val_binary_accuracy: 0.0475 - val_iou: 0.0054 - val_dice_coef: 0.0106
# Epoch 7/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0538 - binary_accuracy: 0.9606 - iou: 0.0282 - dice_coef: 0.0538
# Epoch 7: val_loss did not improve from -0.01496
# 11/11 [==============================] - 87s 9s/step - loss: -0.0538 - binary_accuracy: 0.9606 - iou: 0.0282 - dice_coef: 0.0538 - val_loss: -0.0105 - val_binary_accuracy: 0.1633 - val_iou: 0.0047 - val_dice_coef: 0.0093
# Epoch 8/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0893 - binary_accuracy: 0.9537 - iou: 0.0474 - dice_coef: 0.0892
# Epoch 8: val_loss did not improve from -0.01496
# 11/11 [==============================] - 87s 9s/step - loss: -0.0893 - binary_accuracy: 0.9537 - iou: 0.0474 - dice_coef: 0.0892 - val_loss: -0.0105 - val_binary_accuracy: 0.0175 - val_iou: 0.0058 - val_dice_coef: 0.0113
# Epoch 9/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0398 - binary_accuracy: 0.9054 - iou: 0.0206 - dice_coef: 0.0396
# Epoch 9: val_loss did not improve from -0.01496
# 11/11 [==============================] - 87s 9s/step - loss: -0.0398 - binary_accuracy: 0.9054 - iou: 0.0206 - dice_coef: 0.0396 - val_loss: -0.0011 - val_binary_accuracy: 0.3285 - val_iou: 6.7513e-04 - val_dice_coef: 0.0012
# Epoch 10/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0582 - binary_accuracy: 0.9440 - iou: 0.0296 - dice_coef: 0.0567
# Epoch 10: val_loss did not improve from -0.01496
# 11/11 [==============================] - 87s 9s/step - loss: -0.0582 - binary_accuracy: 0.9440 - iou: 0.0296 - dice_coef: 0.0567 - val_loss: -0.0084 - val_binary_accuracy: 0.1616 - val_iou: 0.0043 - val_dice_coef: 0.0084
# Epoch 11/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0690 - binary_accuracy: 0.9549 - iou: 0.0379 - dice_coef: 0.0712
# Epoch 11: val_loss did not improve from -0.01496
# 11/11 [==============================] - 87s 9s/step - loss: -0.0690 - binary_accuracy: 0.9549 - iou: 0.0379 - dice_coef: 0.0712 - val_loss: -0.0092 - val_binary_accuracy: 0.1523 - val_iou: 0.0041 - val_dice_coef: 0.0080
# Epoch 12/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0869 - binary_accuracy: 0.9820 - iou: 0.0475 - dice_coef: 0.0882
# Epoch 12: val_loss did not improve from -0.01496
# 11/11 [==============================] - 87s 9s/step - loss: -0.0869 - binary_accuracy: 0.9820 - iou: 0.0475 - dice_coef: 0.0882 - val_loss: -0.0103 - val_binary_accuracy: 0.1138 - val_iou: 0.0053 - val_dice_coef: 0.0104
# Epoch 13/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0866 - binary_accuracy: 0.9758 - iou: 0.0470 - dice_coef: 0.0866
# Epoch 13: val_loss did not improve from -0.01496
# 11/11 [==============================] - 87s 9s/step - loss: -0.0866 - binary_accuracy: 0.9758 - iou: 0.0470 - dice_coef: 0.0866 - val_loss: -0.0107 - val_binary_accuracy: 0.1386 - val_iou: 0.0051 - val_dice_coef: 0.0099
# Epoch 14/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0785 - binary_accuracy: 0.9487 - iou: 0.0416 - dice_coef: 0.0773
# Epoch 14: val_loss did not improve from -0.01496
# 11/11 [==============================] - 87s 9s/step - loss: -0.0785 - binary_accuracy: 0.9487 - iou: 0.0416 - dice_coef: 0.0773 - val_loss: -0.0066 - val_binary_accuracy: 0.3526 - val_iou: 0.0037 - val_dice_coef: 0.0073
# Epoch 15/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0644 - binary_accuracy: 0.9718 - iou: 0.0358 - dice_coef: 0.0659
# Epoch 15: val_loss improved from -0.01496 to -0.03595, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 90s 9s/step - loss: -0.0644 - binary_accuracy: 0.9718 - iou: 0.0358 - dice_coef: 0.0659 - val_loss: -0.0360 - val_binary_accuracy: 0.7164 - val_iou: 0.0191 - val_dice_coef: 0.0368
# Epoch 16/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1045 - binary_accuracy: 0.9792 - iou: 0.0572 - dice_coef: 0.1055
# Epoch 16: val_loss improved from -0.03595 to -0.03909, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 92s 9s/step - loss: -0.1045 - binary_accuracy: 0.9792 - iou: 0.0572 - dice_coef: 0.1055 - val_loss: -0.0391 - val_binary_accuracy: 0.8666 - val_iou: 0.0215 - val_dice_coef: 0.0411
# Epoch 17/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1078 - binary_accuracy: 0.9821 - iou: 0.0598 - dice_coef: 0.1096
# Epoch 17: val_loss did not improve from -0.03909
# 11/11 [==============================] - 86s 8s/step - loss: -0.1078 - binary_accuracy: 0.9821 - iou: 0.0598 - dice_coef: 0.1096 - val_loss: -0.0336 - val_binary_accuracy: 0.9947 - val_iou: 0.0215 - val_dice_coef: 0.0350
# Epoch 18/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1106 - binary_accuracy: 0.9816 - iou: 0.0619 - dice_coef: 0.1121
# Epoch 18: val_loss did not improve from -0.03909
# 11/11 [==============================] - 89s 9s/step - loss: -0.1106 - binary_accuracy: 0.9816 - iou: 0.0619 - dice_coef: 0.1121 - val_loss: -0.0024 - val_binary_accuracy: 0.3427 - val_iou: 0.0014 - val_dice_coef: 0.0025
# Epoch 19/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1198 - binary_accuracy: 0.9888 - iou: 0.0662 - dice_coef: 0.1191
# Epoch 19: val_loss did not improve from -0.03909
# 11/11 [==============================] - 88s 9s/step - loss: -0.1198 - binary_accuracy: 0.9888 - iou: 0.0662 - dice_coef: 0.1191 - val_loss: -2.7719e-04 - val_binary_accuracy: 0.3116 - val_iou: 2.8706e-04 - val_dice_coef: 3.9542e-04
# Epoch 20/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1257 - binary_accuracy: 0.9878 - iou: 0.0703 - dice_coef: 0.1222
# Epoch 20: val_loss did not improve from -0.03909
# 11/11 [==============================] - 87s 9s/step - loss: -0.1257 - binary_accuracy: 0.9878 - iou: 0.0703 - dice_coef: 0.1222 - val_loss: -0.0029 - val_binary_accuracy: 0.3093 - val_iou: 0.0013 - val_dice_coef: 0.0024
# Epoch 21/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0902 - binary_accuracy: 0.9877 - iou: 0.0513 - dice_coef: 0.0901
# Epoch 21: val_loss did not improve from -0.03909
# 11/11 [==============================] - 87s 9s/step - loss: -0.0902 - binary_accuracy: 0.9877 - iou: 0.0513 - dice_coef: 0.0901 - val_loss: -0.0086 - val_binary_accuracy: 0.4156 - val_iou: 0.0045 - val_dice_coef: 0.0086
# Epoch 22/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1470 - binary_accuracy: 0.9841 - iou: 0.0803 - dice_coef: 0.1444
# Epoch 22: val_loss improved from -0.03909 to -0.04126, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 90s 9s/step - loss: -0.1470 - binary_accuracy: 0.9841 - iou: 0.0803 - dice_coef: 0.1444 - val_loss: -0.0413 - val_binary_accuracy: 0.9443 - val_iou: 0.0215 - val_dice_coef: 0.0395
# Epoch 23/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1622 - binary_accuracy: 0.9849 - iou: 0.0951 - dice_coef: 0.1664
# Epoch 23: val_loss improved from -0.04126 to -0.04797, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 92s 9s/step - loss: -0.1622 - binary_accuracy: 0.9849 - iou: 0.0951 - dice_coef: 0.1664 - val_loss: -0.0480 - val_binary_accuracy: 0.9723 - val_iou: 0.0220 - val_dice_coef: 0.0405
# Epoch 24/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1537 - binary_accuracy: 0.9881 - iou: 0.0903 - dice_coef: 0.1564
# Epoch 24: val_loss did not improve from -0.04797
# 11/11 [==============================] - 87s 9s/step - loss: -0.1537 - binary_accuracy: 0.9881 - iou: 0.0903 - dice_coef: 0.1564 - val_loss: -0.0223 - val_binary_accuracy: 0.9948 - val_iou: 0.0252 - val_dice_coef: 0.0311
# Epoch 25/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1524 - binary_accuracy: 0.9877 - iou: 0.0839 - dice_coef: 0.1472
# Epoch 25: val_loss did not improve from -0.04797
# 11/11 [==============================] - 87s 9s/step - loss: -0.1524 - binary_accuracy: 0.9877 - iou: 0.0839 - dice_coef: 0.1472 - val_loss: -0.0259 - val_binary_accuracy: 0.9948 - val_iou: 0.0225 - val_dice_coef: 0.0314
# Epoch 26/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0963 - binary_accuracy: 0.9904 - iou: 0.0548 - dice_coef: 0.0948
# Epoch 26: val_loss improved from -0.04797 to -0.07320, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 89s 9s/step - loss: -0.0963 - binary_accuracy: 0.9904 - iou: 0.0548 - dice_coef: 0.0948 - val_loss: -0.0732 - val_binary_accuracy: 0.9768 - val_iou: 0.0354 - val_dice_coef: 0.0626
# Epoch 27/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0226 - binary_accuracy: 0.9877 - iou: 0.0125 - dice_coef: 0.0227
# Epoch 27: val_loss did not improve from -0.07320
# 11/11 [==============================] - 89s 9s/step - loss: -0.0226 - binary_accuracy: 0.9877 - iou: 0.0125 - dice_coef: 0.0227 - val_loss: -0.0331 - val_binary_accuracy: 0.7123 - val_iou: 0.0174 - val_dice_coef: 0.0337
# Epoch 28/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0704 - binary_accuracy: 0.9394 - iou: 0.0372 - dice_coef: 0.0693
# Epoch 28: val_loss did not improve from -0.07320
# 11/11 [==============================] - 88s 9s/step - loss: -0.0704 - binary_accuracy: 0.9394 - iou: 0.0372 - dice_coef: 0.0693 - val_loss: -0.0166 - val_binary_accuracy: 0.2452 - val_iou: 0.0090 - val_dice_coef: 0.0177
# Epoch 29/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0727 - binary_accuracy: 0.9417 - iou: 0.0390 - dice_coef: 0.0733
# Epoch 29: val_loss did not improve from -0.07320
# 11/11 [==============================] - 88s 9s/step - loss: -0.0727 - binary_accuracy: 0.9417 - iou: 0.0390 - dice_coef: 0.0733 - val_loss: -0.0038 - val_binary_accuracy: 0.3798 - val_iou: 0.0022 - val_dice_coef: 0.0041
# Epoch 30/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0802 - binary_accuracy: 0.9671 - iou: 0.0438 - dice_coef: 0.0809
# Epoch 30: val_loss did not improve from -0.07320
# 11/11 [==============================] - 87s 9s/step - loss: -0.0802 - binary_accuracy: 0.9671 - iou: 0.0438 - dice_coef: 0.0809 - val_loss: -0.0109 - val_binary_accuracy: 0.0300 - val_iou: 0.0063 - val_dice_coef: 0.0124
# Epoch 31/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1179 - binary_accuracy: 0.9706 - iou: 0.0643 - dice_coef: 0.1174
# Epoch 31: val_loss did not improve from -0.07320
# 11/11 [==============================] - 88s 9s/step - loss: -0.1179 - binary_accuracy: 0.9706 - iou: 0.0643 - dice_coef: 0.1174 - val_loss: -0.0103 - val_binary_accuracy: 0.0192 - val_iou: 0.0059 - val_dice_coef: 0.0115
# Epoch 32/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1396 - binary_accuracy: 0.9757 - iou: 0.0797 - dice_coef: 0.1429
# Epoch 32: val_loss did not improve from -0.07320
# 11/11 [==============================] - 89s 9s/step - loss: -0.1396 - binary_accuracy: 0.9757 - iou: 0.0797 - dice_coef: 0.1429 - val_loss: -0.0140 - val_binary_accuracy: 0.0835 - val_iou: 0.0085 - val_dice_coef: 0.0167
# Epoch 33/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1073 - binary_accuracy: 0.9776 - iou: 0.0588 - dice_coef: 0.1059
# Epoch 33: val_loss did not improve from -0.07320
# 11/11 [==============================] - 87s 9s/step - loss: -0.1073 - binary_accuracy: 0.9776 - iou: 0.0588 - dice_coef: 0.1059 - val_loss: -0.0309 - val_binary_accuracy: 0.6953 - val_iou: 0.0152 - val_dice_coef: 0.0294
# Epoch 34/300
# 11/11 [==============================] - ETA: 0s - loss: -0.0993 - binary_accuracy: 0.9850 - iou: 0.0543 - dice_coef: 0.0973
# Epoch 34: val_loss did not improve from -0.07320
# 11/11 [==============================] - 88s 9s/step - loss: -0.0993 - binary_accuracy: 0.9850 - iou: 0.0543 - dice_coef: 0.0973 - val_loss: -0.0320 - val_binary_accuracy: 0.9746 - val_iou: 0.0255 - val_dice_coef: 0.0476
# Epoch 35/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1271 - binary_accuracy: 0.9678 - iou: 0.0693 - dice_coef: 0.1262
# Epoch 35: val_loss did not improve from -0.07320
# 11/11 [==============================] - 88s 9s/step - loss: -0.1271 - binary_accuracy: 0.9678 - iou: 0.0693 - dice_coef: 0.1262 - val_loss: -3.2281e-04 - val_binary_accuracy: 0.3611 - val_iou: 3.3502e-04 - val_dice_coef: 4.4707e-04
# Epoch 36/300
# 11/11 [==============================] - ETA: 0s - loss: -0.1779 - binary_accuracy: 0.9869 - iou: 0.1031 - dice_coef: 0.1782
# Epoch 36: val_loss did not improve from -0.07320
# 11/11 [==============================] - 87s 9s/step - loss: -0.1779 - binary_accuracy: 0.9869 - iou: 0.1031 - dice_coef: 0.1782 - val_loss: -0.0013 - val_binary_accuracy: 0.3595 - val_iou: 5.8527e-04 - val_dice_coef: 9.6921e-04
# Epoch 37/300
# 11/11 [==============================] - ETA: 0s - loss: -0.2298 - binary_accuracy: 0.9906 - iou: 0.1368 - dice_coef: 0.2300
# Epoch 37: val_loss did not improve from -0.07320
# 11/11 [==============================] - 89s 9s/step - loss: -0.2298 - binary_accuracy: 0.9906 - iou: 0.1368 - dice_coef: 0.2300 - val_loss: -4.2542e-04 - val_binary_accuracy: 0.3647 - val_iou: 2.9699e-04 - val_dice_coef: 4.0262e-04
# Epoch 38/300
# 11/11 [==============================] - ETA: 0s - loss: -0.2080 - binary_accuracy: 0.9889 - iou: 0.1212 - dice_coef: 0.2091
# Epoch 38: val_loss did not improve from -0.07320
# 11/11 [==============================] - 87s 9s/step - loss: -0.2080 - binary_accuracy: 0.9889 - iou: 0.1212 - dice_coef: 0.2091 - val_loss: -0.0018 - val_binary_accuracy: 0.3754 - val_iou: 0.0015 - val_dice_coef: 0.0028
# Epoch 39/300
# 11/11 [==============================] - ETA: 0s - loss: -0.2100 - binary_accuracy: 0.9896 - iou: 0.1239 - dice_coef: 0.2089
# Epoch 39: val_loss did not improve from -0.07320
# 11/11 [==============================] - 87s 9s/step - loss: -0.2100 - binary_accuracy: 0.9896 - iou: 0.1239 - dice_coef: 0.2089 - val_loss: -0.0026 - val_binary_accuracy: 0.3737 - val_iou: 0.0015 - val_dice_coef: 0.0027
# Epoch 40/300
# 11/11 [==============================] - ETA: 0s - loss: -0.2871 - binary_accuracy: 0.9923 - iou: 0.1705 - dice_coef: 0.2819
# Epoch 40: val_loss did not improve from -0.07320
# 11/11 [==============================] - 86s 9s/step - loss: -0.2871 - binary_accuracy: 0.9923 - iou: 0.1705 - dice_coef: 0.2819 - val_loss: -3.4814e-04 - val_binary_accuracy: 0.3574 - val_iou: 2.7616e-04 - val_dice_coef: 3.6648e-04
# Epoch 41/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3250 - binary_accuracy: 0.9934 - iou: 0.2074 - dice_coef: 0.3304
# Epoch 41: val_loss did not improve from -0.07320
# 11/11 [==============================] - 87s 9s/step - loss: -0.3250 - binary_accuracy: 0.9934 - iou: 0.2074 - dice_coef: 0.3304 - val_loss: -0.0016 - val_binary_accuracy: 0.3590 - val_iou: 0.0012 - val_dice_coef: 0.0022
# Epoch 42/300
# 11/11 [==============================] - ETA: 0s - loss: -0.2877 - binary_accuracy: 0.9926 - iou: 0.1755 - dice_coef: 0.2871
# Epoch 42: val_loss did not improve from -0.07320
# 11/11 [==============================] - 87s 9s/step - loss: -0.2877 - binary_accuracy: 0.9926 - iou: 0.1755 - dice_coef: 0.2871 - val_loss: -2.5672e-04 - val_binary_accuracy: 0.3564 - val_iou: 2.7174e-04 - val_dice_coef: 3.5225e-04
# Epoch 43/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3146 - binary_accuracy: 0.9933 - iou: 0.1933 - dice_coef: 0.3130
# Epoch 43: val_loss did not improve from -0.07320
# 11/11 [==============================] - 88s 9s/step - loss: -0.3146 - binary_accuracy: 0.9933 - iou: 0.1933 - dice_coef: 0.3130 - val_loss: -1.7111e-04 - val_binary_accuracy: 0.3763 - val_iou: 2.2689e-04 - val_dice_coef: 2.4855e-04
# Epoch 44/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3167 - binary_accuracy: 0.9939 - iou: 0.2024 - dice_coef: 0.3184
# Epoch 44: val_loss did not improve from -0.07320
# 11/11 [==============================] - 87s 9s/step - loss: -0.3167 - binary_accuracy: 0.9939 - iou: 0.2024 - dice_coef: 0.3184 - val_loss: -0.0023 - val_binary_accuracy: 0.3738 - val_iou: 0.0010 - val_dice_coef: 0.0018
# Epoch 45/300
# 11/11 [==============================] - ETA: 0s - loss: -0.2950 - binary_accuracy: 0.9934 - iou: 0.1844 - dice_coef: 0.2953
# Epoch 45: val_loss did not improve from -0.07320
# 11/11 [==============================] - 87s 9s/step - loss: -0.2950 - binary_accuracy: 0.9934 - iou: 0.1844 - dice_coef: 0.2953 - val_loss: -0.0199 - val_binary_accuracy: 0.9955 - val_iou: 0.0092 - val_dice_coef: 0.0169
# Epoch 46/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3324 - binary_accuracy: 0.9922 - iou: 0.2086 - dice_coef: 0.3315
# Epoch 46: val_loss did not improve from -0.07320
# 11/11 [==============================] - 88s 9s/step - loss: -0.3324 - binary_accuracy: 0.9922 - iou: 0.2086 - dice_coef: 0.3315 - val_loss: -0.0025 - val_binary_accuracy: 0.4158 - val_iou: 0.0014 - val_dice_coef: 0.0027
# Epoch 47/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3576 - binary_accuracy: 0.9944 - iou: 0.2314 - dice_coef: 0.3593
# Epoch 47: val_loss did not improve from -0.07320
# 11/11 [==============================] - 87s 9s/step - loss: -0.3576 - binary_accuracy: 0.9944 - iou: 0.2314 - dice_coef: 0.3593 - val_loss: -0.0546 - val_binary_accuracy: 0.8888 - val_iou: 0.0343 - val_dice_coef: 0.0647
# Epoch 48/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4080 - binary_accuracy: 0.9943 - iou: 0.2690 - dice_coef: 0.4065
# Epoch 48: val_loss improved from -0.07320 to -0.09121, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 92s 9s/step - loss: -0.4080 - binary_accuracy: 0.9943 - iou: 0.2690 - dice_coef: 0.4065 - val_loss: -0.0912 - val_binary_accuracy: 0.9829 - val_iou: 0.0417 - val_dice_coef: 0.0752
# Epoch 49/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3161 - binary_accuracy: 0.9943 - iou: 0.2095 - dice_coef: 0.3202
# Epoch 49: val_loss did not improve from -0.09121
# 11/11 [==============================] - 88s 9s/step - loss: -0.3161 - binary_accuracy: 0.9943 - iou: 0.2095 - dice_coef: 0.3202 - val_loss: -0.0186 - val_binary_accuracy: 0.9335 - val_iou: 0.0103 - val_dice_coef: 0.0198
# Epoch 50/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3910 - binary_accuracy: 0.9938 - iou: 0.2491 - dice_coef: 0.3861
# Epoch 50: val_loss did not improve from -0.09121
# 11/11 [==============================] - 88s 9s/step - loss: -0.3910 - binary_accuracy: 0.9938 - iou: 0.2491 - dice_coef: 0.3861 - val_loss: -0.0067 - val_binary_accuracy: 0.2898 - val_iou: 0.0037 - val_dice_coef: 0.0073
# Epoch 51/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3547 - binary_accuracy: 0.9927 - iou: 0.2264 - dice_coef: 0.3497
# Epoch 51: val_loss did not improve from -0.09121
# 11/11 [==============================] - 87s 9s/step - loss: -0.3547 - binary_accuracy: 0.9927 - iou: 0.2264 - dice_coef: 0.3497 - val_loss: -0.0055 - val_binary_accuracy: 0.3565 - val_iou: 0.0026 - val_dice_coef: 0.0050
# Epoch 52/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3530 - binary_accuracy: 0.9946 - iou: 0.2315 - dice_coef: 0.3533
# Epoch 52: val_loss did not improve from -0.09121
# 11/11 [==============================] - 87s 9s/step - loss: -0.3530 - binary_accuracy: 0.9946 - iou: 0.2315 - dice_coef: 0.3533 - val_loss: -0.0232 - val_binary_accuracy: 0.9654 - val_iou: 0.0171 - val_dice_coef: 0.0303
# Epoch 53/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3572 - binary_accuracy: 0.9938 - iou: 0.2332 - dice_coef: 0.3556
# Epoch 53: val_loss improved from -0.09121 to -0.13659, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 91s 9s/step - loss: -0.3572 - binary_accuracy: 0.9938 - iou: 0.2332 - dice_coef: 0.3556 - val_loss: -0.1366 - val_binary_accuracy: 0.9758 - val_iou: 0.0694 - val_dice_coef: 0.1233
# Epoch 54/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3687 - binary_accuracy: 0.9946 - iou: 0.2364 - dice_coef: 0.3595
# Epoch 54: val_loss did not improve from -0.13659
# 11/11 [==============================] - 88s 9s/step - loss: -0.3687 - binary_accuracy: 0.9946 - iou: 0.2364 - dice_coef: 0.3595 - val_loss: -0.0714 - val_binary_accuracy: 0.9542 - val_iou: 0.0392 - val_dice_coef: 0.0713
# Epoch 55/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4023 - binary_accuracy: 0.9953 - iou: 0.2615 - dice_coef: 0.3934
# Epoch 55: val_loss improved from -0.13659 to -0.16943, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 90s 9s/step - loss: -0.4023 - binary_accuracy: 0.9953 - iou: 0.2615 - dice_coef: 0.3934 - val_loss: -0.1694 - val_binary_accuracy: 0.9873 - val_iou: 0.1038 - val_dice_coef: 0.1745
# Epoch 56/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3746 - binary_accuracy: 0.9945 - iou: 0.2449 - dice_coef: 0.3781
# Epoch 56: val_loss did not improve from -0.16943
# 11/11 [==============================] - 88s 9s/step - loss: -0.3746 - binary_accuracy: 0.9945 - iou: 0.2449 - dice_coef: 0.3781 - val_loss: -0.1067 - val_binary_accuracy: 0.9656 - val_iou: 0.0530 - val_dice_coef: 0.0974
# Epoch 57/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4492 - binary_accuracy: 0.9951 - iou: 0.3035 - dice_coef: 0.4460
# Epoch 57: val_loss improved from -0.16943 to -0.30697, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 89s 9s/step - loss: -0.4492 - binary_accuracy: 0.9951 - iou: 0.3035 - dice_coef: 0.4460 - val_loss: -0.3070 - val_binary_accuracy: 0.9915 - val_iou: 0.1662 - val_dice_coef: 0.2600
# Epoch 58/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3530 - binary_accuracy: 0.9941 - iou: 0.2280 - dice_coef: 0.3502
# Epoch 58: val_loss did not improve from -0.30697
# 11/11 [==============================] - 91s 9s/step - loss: -0.3530 - binary_accuracy: 0.9941 - iou: 0.2280 - dice_coef: 0.3502 - val_loss: -0.0932 - val_binary_accuracy: 0.9400 - val_iou: 0.0583 - val_dice_coef: 0.1067
# Epoch 59/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3954 - binary_accuracy: 0.9948 - iou: 0.2589 - dice_coef: 0.3904
# Epoch 59: val_loss improved from -0.30697 to -0.31759, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 91s 9s/step - loss: -0.3954 - binary_accuracy: 0.9948 - iou: 0.2589 - dice_coef: 0.3904 - val_loss: -0.3176 - val_binary_accuracy: 0.9942 - val_iou: 0.2000 - val_dice_coef: 0.3135
# Epoch 60/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4225 - binary_accuracy: 0.9954 - iou: 0.2761 - dice_coef: 0.4166
# Epoch 60: val_loss did not improve from -0.31759
# 11/11 [==============================] - 88s 9s/step - loss: -0.4225 - binary_accuracy: 0.9954 - iou: 0.2761 - dice_coef: 0.4166 - val_loss: -0.2634 - val_binary_accuracy: 0.9945 - val_iou: 0.1241 - val_dice_coef: 0.1899
# Epoch 61/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4038 - binary_accuracy: 0.9946 - iou: 0.2658 - dice_coef: 0.3999
# Epoch 61: val_loss improved from -0.31759 to -0.32198, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 90s 9s/step - loss: -0.4038 - binary_accuracy: 0.9946 - iou: 0.2658 - dice_coef: 0.3999 - val_loss: -0.3220 - val_binary_accuracy: 0.9953 - val_iou: 0.1799 - val_dice_coef: 0.2667
# Epoch 62/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3878 - binary_accuracy: 0.9944 - iou: 0.2597 - dice_coef: 0.3909
# Epoch 62: val_loss did not improve from -0.32198
# 11/11 [==============================] - 88s 9s/step - loss: -0.3878 - binary_accuracy: 0.9944 - iou: 0.2597 - dice_coef: 0.3909 - val_loss: -0.1521 - val_binary_accuracy: 0.9806 - val_iou: 0.0904 - val_dice_coef: 0.1592
# Epoch 63/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4086 - binary_accuracy: 0.9937 - iou: 0.2692 - dice_coef: 0.4093
# Epoch 63: val_loss did not improve from -0.32198
# 11/11 [==============================] - 86s 8s/step - loss: -0.4086 - binary_accuracy: 0.9937 - iou: 0.2692 - dice_coef: 0.4093 - val_loss: -0.2698 - val_binary_accuracy: 0.9932 - val_iou: 0.2101 - val_dice_coef: 0.3234
# Epoch 64/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3578 - binary_accuracy: 0.9945 - iou: 0.2309 - dice_coef: 0.3540
# Epoch 64: val_loss did not improve from -0.32198
# 11/11 [==============================] - 86s 8s/step - loss: -0.3578 - binary_accuracy: 0.9945 - iou: 0.2309 - dice_coef: 0.3540 - val_loss: -0.2875 - val_binary_accuracy: 0.9941 - val_iou: 0.1569 - val_dice_coef: 0.2410
# Epoch 65/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4536 - binary_accuracy: 0.9953 - iou: 0.3009 - dice_coef: 0.4492
# Epoch 65: val_loss did not improve from -0.32198
# 11/11 [==============================] - 95s 9s/step - loss: -0.4536 - binary_accuracy: 0.9953 - iou: 0.3009 - dice_coef: 0.4492 - val_loss: -0.2918 - val_binary_accuracy: 0.9940 - val_iou: 0.2218 - val_dice_coef: 0.3303
# Epoch 66/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4496 - binary_accuracy: 0.9955 - iou: 0.2990 - dice_coef: 0.4509
# Epoch 66: val_loss did not improve from -0.32198
# 11/11 [==============================] - 86s 8s/step - loss: -0.4496 - binary_accuracy: 0.9955 - iou: 0.2990 - dice_coef: 0.4509 - val_loss: -0.3121 - val_binary_accuracy: 0.9951 - val_iou: 0.2320 - val_dice_coef: 0.3375
# Epoch 67/300
# 11/11 [==============================] - ETA: 0s - loss: -0.3857 - binary_accuracy: 0.9947 - iou: 0.2578 - dice_coef: 0.3891
# Epoch 67: val_loss did not improve from -0.32198
# 11/11 [==============================] - 87s 9s/step - loss: -0.3857 - binary_accuracy: 0.9947 - iou: 0.2578 - dice_coef: 0.3891 - val_loss: -0.1240 - val_binary_accuracy: 0.9751 - val_iou: 0.0745 - val_dice_coef: 0.1311
# Epoch 68/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4088 - binary_accuracy: 0.9942 - iou: 0.2788 - dice_coef: 0.4157
# Epoch 68: val_loss did not improve from -0.32198
# 11/11 [==============================] - 86s 8s/step - loss: -0.4088 - binary_accuracy: 0.9942 - iou: 0.2788 - dice_coef: 0.4157 - val_loss: -0.3076 - val_binary_accuracy: 0.9918 - val_iou: 0.1947 - val_dice_coef: 0.3006
# Epoch 69/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4326 - binary_accuracy: 0.9947 - iou: 0.3077 - dice_coef: 0.4371
# Epoch 69: val_loss improved from -0.32198 to -0.34477, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 87s 9s/step - loss: -0.4326 - binary_accuracy: 0.9947 - iou: 0.3077 - dice_coef: 0.4371 - val_loss: -0.3448 - val_binary_accuracy: 0.9949 - val_iou: 0.2196 - val_dice_coef: 0.3406
# Epoch 70/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5174 - binary_accuracy: 0.9953 - iou: 0.3603 - dice_coef: 0.5085
# Epoch 70: val_loss did not improve from -0.34477
# 11/11 [==============================] - 87s 9s/step - loss: -0.5174 - binary_accuracy: 0.9953 - iou: 0.3603 - dice_coef: 0.5085 - val_loss: -0.2782 - val_binary_accuracy: 0.9933 - val_iou: 0.1311 - val_dice_coef: 0.2100
# Epoch 71/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4711 - binary_accuracy: 0.9954 - iou: 0.3261 - dice_coef: 0.4676
# Epoch 71: val_loss improved from -0.34477 to -0.37395, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 89s 9s/step - loss: -0.4711 - binary_accuracy: 0.9954 - iou: 0.3261 - dice_coef: 0.4676 - val_loss: -0.3740 - val_binary_accuracy: 0.9944 - val_iou: 0.1951 - val_dice_coef: 0.3077
# Epoch 72/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4368 - binary_accuracy: 0.9952 - iou: 0.3015 - dice_coef: 0.4320
# Epoch 72: val_loss did not improve from -0.37395
# 11/11 [==============================] - 87s 8s/step - loss: -0.4368 - binary_accuracy: 0.9952 - iou: 0.3015 - dice_coef: 0.4320 - val_loss: -0.0824 - val_binary_accuracy: 0.9154 - val_iou: 0.0451 - val_dice_coef: 0.0845
# Epoch 73/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4673 - binary_accuracy: 0.9952 - iou: 0.3271 - dice_coef: 0.4685
# Epoch 73: val_loss did not improve from -0.37395
# 11/11 [==============================] - 87s 9s/step - loss: -0.4673 - binary_accuracy: 0.9952 - iou: 0.3271 - dice_coef: 0.4685 - val_loss: -0.1826 - val_binary_accuracy: 0.9647 - val_iou: 0.0933 - val_dice_coef: 0.1659
# Epoch 74/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4462 - binary_accuracy: 0.9950 - iou: 0.3114 - dice_coef: 0.4486
# Epoch 74: val_loss did not improve from -0.37395
# 11/11 [==============================] - 85s 8s/step - loss: -0.4462 - binary_accuracy: 0.9950 - iou: 0.3114 - dice_coef: 0.4486 - val_loss: -0.2829 - val_binary_accuracy: 0.9944 - val_iou: 0.1737 - val_dice_coef: 0.2599
# Epoch 75/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4607 - binary_accuracy: 0.9950 - iou: 0.3146 - dice_coef: 0.4563
# Epoch 75: val_loss did not improve from -0.37395
# 11/11 [==============================] - 86s 8s/step - loss: -0.4607 - binary_accuracy: 0.9950 - iou: 0.3146 - dice_coef: 0.4563 - val_loss: -0.0558 - val_binary_accuracy: 0.9947 - val_iou: 0.1178 - val_dice_coef: 0.1282
# Epoch 76/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4683 - binary_accuracy: 0.9954 - iou: 0.3241 - dice_coef: 0.4660
# Epoch 76: val_loss did not improve from -0.37395
# 11/11 [==============================] - 94s 9s/step - loss: -0.4683 - binary_accuracy: 0.9954 - iou: 0.3241 - dice_coef: 0.4660 - val_loss: -0.0557 - val_binary_accuracy: 0.9946 - val_iou: 0.1401 - val_dice_coef: 0.1428
# Epoch 77/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4717 - binary_accuracy: 0.9957 - iou: 0.3265 - dice_coef: 0.4712
# Epoch 77: val_loss did not improve from -0.37395
# 11/11 [==============================] - 86s 8s/step - loss: -0.4717 - binary_accuracy: 0.9957 - iou: 0.3265 - dice_coef: 0.4712 - val_loss: -0.1111 - val_binary_accuracy: 0.9948 - val_iou: 0.0828 - val_dice_coef: 0.1162
# Epoch 78/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4703 - binary_accuracy: 0.9953 - iou: 0.3312 - dice_coef: 0.4696
# Epoch 78: val_loss did not improve from -0.37395
# 11/11 [==============================] - 87s 9s/step - loss: -0.4703 - binary_accuracy: 0.9953 - iou: 0.3312 - dice_coef: 0.4696 - val_loss: -0.2414 - val_binary_accuracy: 0.9854 - val_iou: 0.1268 - val_dice_coef: 0.2166
# Epoch 79/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5055 - binary_accuracy: 0.9957 - iou: 0.3595 - dice_coef: 0.5067
# Epoch 79: val_loss did not improve from -0.37395
# 11/11 [==============================] - 85s 8s/step - loss: -0.5055 - binary_accuracy: 0.9957 - iou: 0.3595 - dice_coef: 0.5067 - val_loss: -0.0959 - val_binary_accuracy: 0.9376 - val_iou: 0.0539 - val_dice_coef: 0.0999
# Epoch 80/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4659 - binary_accuracy: 0.9951 - iou: 0.3122 - dice_coef: 0.4554
# Epoch 80: val_loss did not improve from -0.37395
# 11/11 [==============================] - 85s 8s/step - loss: -0.4659 - binary_accuracy: 0.9951 - iou: 0.3122 - dice_coef: 0.4554 - val_loss: -0.2449 - val_binary_accuracy: 0.9917 - val_iou: 0.1306 - val_dice_coef: 0.2071
# Epoch 81/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4830 - binary_accuracy: 0.9955 - iou: 0.3387 - dice_coef: 0.4832
# Epoch 81: val_loss did not improve from -0.37395
# 11/11 [==============================] - 86s 8s/step - loss: -0.4830 - binary_accuracy: 0.9955 - iou: 0.3387 - dice_coef: 0.4832 - val_loss: -0.3199 - val_binary_accuracy: 0.9951 - val_iou: 0.2039 - val_dice_coef: 0.3058
# Epoch 82/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4975 - binary_accuracy: 0.9955 - iou: 0.3490 - dice_coef: 0.4960
# Epoch 82: val_loss did not improve from -0.37395
# 11/11 [==============================] - 88s 9s/step - loss: -0.4975 - binary_accuracy: 0.9955 - iou: 0.3490 - dice_coef: 0.4960 - val_loss: -0.2942 - val_binary_accuracy: 0.9950 - val_iou: 0.1706 - val_dice_coef: 0.2577
# Epoch 83/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4688 - binary_accuracy: 0.9960 - iou: 0.3314 - dice_coef: 0.4769
# Epoch 83: val_loss did not improve from -0.37395
# 11/11 [==============================] - 85s 8s/step - loss: -0.4688 - binary_accuracy: 0.9960 - iou: 0.3314 - dice_coef: 0.4769 - val_loss: -0.0466 - val_binary_accuracy: 0.9946 - val_iou: 0.1209 - val_dice_coef: 0.1209
# Epoch 84/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4643 - binary_accuracy: 0.9949 - iou: 0.3382 - dice_coef: 0.4718
# Epoch 84: val_loss did not improve from -0.37395
# 11/11 [==============================] - 86s 8s/step - loss: -0.4643 - binary_accuracy: 0.9949 - iou: 0.3382 - dice_coef: 0.4718 - val_loss: -0.1473 - val_binary_accuracy: 0.9951 - val_iou: 0.0888 - val_dice_coef: 0.1403
# Epoch 85/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4657 - binary_accuracy: 0.9956 - iou: 0.3126 - dice_coef: 0.4526
# Epoch 85: val_loss did not improve from -0.37395
# 11/11 [==============================] - 86s 8s/step - loss: -0.4657 - binary_accuracy: 0.9956 - iou: 0.3126 - dice_coef: 0.4526 - val_loss: -0.0130 - val_binary_accuracy: 0.9947 - val_iou: 0.0191 - val_dice_coef: 0.0191
# Epoch 86/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4915 - binary_accuracy: 0.9957 - iou: 0.3450 - dice_coef: 0.4948
# Epoch 86: val_loss did not improve from -0.37395
# 11/11 [==============================] - 84s 8s/step - loss: -0.4915 - binary_accuracy: 0.9957 - iou: 0.3450 - dice_coef: 0.4948 - val_loss: -0.0135 - val_binary_accuracy: 0.9947 - val_iou: 0.0201 - val_dice_coef: 0.0201
# Epoch 87/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5123 - binary_accuracy: 0.9957 - iou: 0.3699 - dice_coef: 0.5158
# Epoch 87: val_loss did not improve from -0.37395
# 11/11 [==============================] - 86s 8s/step - loss: -0.5123 - binary_accuracy: 0.9957 - iou: 0.3699 - dice_coef: 0.5158 - val_loss: -0.0188 - val_binary_accuracy: 0.9947 - val_iou: 0.0328 - val_dice_coef: 0.0335
# Epoch 88/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4927 - binary_accuracy: 0.9954 - iou: 0.3479 - dice_coef: 0.4943
# Epoch 88: val_loss did not improve from -0.37395
# 11/11 [==============================] - 85s 8s/step - loss: -0.4927 - binary_accuracy: 0.9954 - iou: 0.3479 - dice_coef: 0.4943 - val_loss: -0.0237 - val_binary_accuracy: 0.9948 - val_iou: 0.0498 - val_dice_coef: 0.0498
# Epoch 89/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4815 - binary_accuracy: 0.9962 - iou: 0.3340 - dice_coef: 0.4820
# Epoch 89: val_loss did not improve from -0.37395
# 11/11 [==============================] - 86s 8s/step - loss: -0.4815 - binary_accuracy: 0.9962 - iou: 0.3340 - dice_coef: 0.4820 - val_loss: -0.0191 - val_binary_accuracy: 0.9946 - val_iou: 0.0399 - val_dice_coef: 0.0400
# Epoch 90/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4802 - binary_accuracy: 0.9957 - iou: 0.3336 - dice_coef: 0.4730
# Epoch 90: val_loss did not improve from -0.37395
# 11/11 [==============================] - 86s 8s/step - loss: -0.4802 - binary_accuracy: 0.9957 - iou: 0.3336 - dice_coef: 0.4730 - val_loss: -0.3057 - val_binary_accuracy: 0.9922 - val_iou: 0.1887 - val_dice_coef: 0.2966
# Epoch 91/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5085 - binary_accuracy: 0.9958 - iou: 0.3576 - dice_coef: 0.5068
# Epoch 91: val_loss did not improve from -0.37395
# 11/11 [==============================] - 85s 8s/step - loss: -0.5085 - binary_accuracy: 0.9958 - iou: 0.3576 - dice_coef: 0.5068 - val_loss: -0.3122 - val_binary_accuracy: 0.9925 - val_iou: 0.1854 - val_dice_coef: 0.2982
# Epoch 92/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5503 - binary_accuracy: 0.9965 - iou: 0.4040 - dice_coef: 0.5513
# Epoch 92: val_loss improved from -0.37395 to -0.38044, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 90s 9s/step - loss: -0.5503 - binary_accuracy: 0.9965 - iou: 0.4040 - dice_coef: 0.5513 - val_loss: -0.3804 - val_binary_accuracy: 0.9930 - val_iou: 0.2140 - val_dice_coef: 0.3342
# Epoch 93/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5349 - binary_accuracy: 0.9963 - iou: 0.3864 - dice_coef: 0.5337
# Epoch 93: val_loss did not improve from -0.38044
# 11/11 [==============================] - 86s 8s/step - loss: -0.5349 - binary_accuracy: 0.9963 - iou: 0.3864 - dice_coef: 0.5337 - val_loss: -0.3691 - val_binary_accuracy: 0.9942 - val_iou: 0.2737 - val_dice_coef: 0.4122
# Epoch 94/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4890 - binary_accuracy: 0.9959 - iou: 0.3418 - dice_coef: 0.4869
# Epoch 94: val_loss did not improve from -0.38044
# 11/11 [==============================] - 85s 8s/step - loss: -0.4890 - binary_accuracy: 0.9959 - iou: 0.3418 - dice_coef: 0.4869 - val_loss: -0.3033 - val_binary_accuracy: 0.9934 - val_iou: 0.1622 - val_dice_coef: 0.2610
# Epoch 95/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5570 - binary_accuracy: 0.9963 - iou: 0.4029 - dice_coef: 0.5513
# Epoch 95: val_loss did not improve from -0.38044
# 11/11 [==============================] - 85s 8s/step - loss: -0.5570 - binary_accuracy: 0.9963 - iou: 0.4029 - dice_coef: 0.5513 - val_loss: -0.0150 - val_binary_accuracy: 0.9948 - val_iou: 0.0216 - val_dice_coef: 0.0216
# Epoch 96/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5017 - binary_accuracy: 0.9960 - iou: 0.3596 - dice_coef: 0.5032
# Epoch 96: val_loss did not improve from -0.38044
# 11/11 [==============================] - 94s 9s/step - loss: -0.5017 - binary_accuracy: 0.9960 - iou: 0.3596 - dice_coef: 0.5032 - val_loss: -0.0228 - val_binary_accuracy: 0.9946 - val_iou: 0.0496 - val_dice_coef: 0.0496
# Epoch 97/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5558 - binary_accuracy: 0.9960 - iou: 0.4139 - dice_coef: 0.5595
# Epoch 97: val_loss did not improve from -0.38044
# 11/11 [==============================] - 86s 8s/step - loss: -0.5558 - binary_accuracy: 0.9960 - iou: 0.4139 - dice_coef: 0.5595 - val_loss: -0.0162 - val_binary_accuracy: 0.9949 - val_iou: 0.0283 - val_dice_coef: 0.0283
# Epoch 98/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5465 - binary_accuracy: 0.9966 - iou: 0.4002 - dice_coef: 0.5500
# Epoch 98: val_loss did not improve from -0.38044
# 11/11 [==============================] - 84s 8s/step - loss: -0.5465 - binary_accuracy: 0.9966 - iou: 0.4002 - dice_coef: 0.5500 - val_loss: -0.1167 - val_binary_accuracy: 0.9949 - val_iou: 0.1055 - val_dice_coef: 0.1503
# Epoch 99/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5368 - binary_accuracy: 0.9955 - iou: 0.4003 - dice_coef: 0.5398
# Epoch 99: val_loss did not improve from -0.38044
# 11/11 [==============================] - 85s 8s/step - loss: -0.5368 - binary_accuracy: 0.9955 - iou: 0.4003 - dice_coef: 0.5398 - val_loss: -0.3487 - val_binary_accuracy: 0.9935 - val_iou: 0.2427 - val_dice_coef: 0.3631
# Epoch 100/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5723 - binary_accuracy: 0.9965 - iou: 0.4174 - dice_coef: 0.5635
# Epoch 100: val_loss did not improve from -0.38044
# 11/11 [==============================] - 85s 8s/step - loss: -0.5723 - binary_accuracy: 0.9965 - iou: 0.4174 - dice_coef: 0.5635 - val_loss: -0.3652 - val_binary_accuracy: 0.9943 - val_iou: 0.2776 - val_dice_coef: 0.4176
# Epoch 101/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5718 - binary_accuracy: 0.9962 - iou: 0.4285 - dice_coef: 0.5774
# Epoch 101: val_loss did not improve from -0.38044
# 11/11 [==============================] - 85s 8s/step - loss: -0.5718 - binary_accuracy: 0.9962 - iou: 0.4285 - dice_coef: 0.5774 - val_loss: -0.0200 - val_binary_accuracy: 0.9948 - val_iou: 0.0416 - val_dice_coef: 0.0417
# Epoch 102/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5309 - binary_accuracy: 0.9963 - iou: 0.3850 - dice_coef: 0.5328
# Epoch 102: val_loss did not improve from -0.38044
# 11/11 [==============================] - 86s 8s/step - loss: -0.5309 - binary_accuracy: 0.9963 - iou: 0.3850 - dice_coef: 0.5328 - val_loss: -0.0180 - val_binary_accuracy: 0.9947 - val_iou: 0.0350 - val_dice_coef: 0.0350
# Epoch 103/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4929 - binary_accuracy: 0.9961 - iou: 0.3657 - dice_coef: 0.4989
# Epoch 103: val_loss did not improve from -0.38044
# 11/11 [==============================] - 85s 8s/step - loss: -0.4929 - binary_accuracy: 0.9961 - iou: 0.3657 - dice_coef: 0.4989 - val_loss: -0.0784 - val_binary_accuracy: 0.9947 - val_iou: 0.1821 - val_dice_coef: 0.1863
# Epoch 104/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5202 - binary_accuracy: 0.9959 - iou: 0.3696 - dice_coef: 0.5198
# Epoch 104: val_loss did not improve from -0.38044
# 11/11 [==============================] - 85s 8s/step - loss: -0.5202 - binary_accuracy: 0.9959 - iou: 0.3696 - dice_coef: 0.5198 - val_loss: -0.3155 - val_binary_accuracy: 0.9934 - val_iou: 0.1660 - val_dice_coef: 0.2567
# Epoch 105/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5249 - binary_accuracy: 0.9963 - iou: 0.3717 - dice_coef: 0.5198
# Epoch 105: val_loss did not improve from -0.38044
# 11/11 [==============================] - 85s 8s/step - loss: -0.5249 - binary_accuracy: 0.9963 - iou: 0.3717 - dice_coef: 0.5198 - val_loss: -0.3684 - val_binary_accuracy: 0.9946 - val_iou: 0.3078 - val_dice_coef: 0.4290
# Epoch 106/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5424 - binary_accuracy: 0.9961 - iou: 0.3948 - dice_coef: 0.5477
# Epoch 106: val_loss did not improve from -0.38044
# 11/11 [==============================] - 86s 8s/step - loss: -0.5424 - binary_accuracy: 0.9961 - iou: 0.3948 - dice_coef: 0.5477 - val_loss: -0.2602 - val_binary_accuracy: 0.9883 - val_iou: 0.1876 - val_dice_coef: 0.3034
# Epoch 107/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5131 - binary_accuracy: 0.9953 - iou: 0.3768 - dice_coef: 0.5142
# Epoch 107: val_loss did not improve from -0.38044
# 11/11 [==============================] - 86s 8s/step - loss: -0.5131 - binary_accuracy: 0.9953 - iou: 0.3768 - dice_coef: 0.5142 - val_loss: -0.0561 - val_binary_accuracy: 0.9947 - val_iou: 0.0576 - val_dice_coef: 0.0685
# Epoch 108/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5169 - binary_accuracy: 0.9963 - iou: 0.3767 - dice_coef: 0.5235
# Epoch 108: val_loss did not improve from -0.38044
# 11/11 [==============================] - 86s 8s/step - loss: -0.5169 - binary_accuracy: 0.9963 - iou: 0.3767 - dice_coef: 0.5235 - val_loss: -0.3036 - val_binary_accuracy: 0.9952 - val_iou: 0.1366 - val_dice_coef: 0.2139
# Epoch 109/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5371 - binary_accuracy: 0.9958 - iou: 0.3859 - dice_coef: 0.5378
# Epoch 109: val_loss did not improve from -0.38044
# 11/11 [==============================] - 84s 8s/step - loss: -0.5371 - binary_accuracy: 0.9958 - iou: 0.3859 - dice_coef: 0.5378 - val_loss: -0.3557 - val_binary_accuracy: 0.9946 - val_iou: 0.2269 - val_dice_coef: 0.3495
# Epoch 110/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5877 - binary_accuracy: 0.9966 - iou: 0.4303 - dice_coef: 0.5720
# Epoch 110: val_loss did not improve from -0.38044
# 11/11 [==============================] - 85s 8s/step - loss: -0.5877 - binary_accuracy: 0.9966 - iou: 0.4303 - dice_coef: 0.5720 - val_loss: -0.3373 - val_binary_accuracy: 0.9950 - val_iou: 0.2035 - val_dice_coef: 0.2931
# Epoch 111/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5753 - binary_accuracy: 0.9962 - iou: 0.4184 - dice_coef: 0.5749
# Epoch 111: val_loss did not improve from -0.38044
# 11/11 [==============================] - 86s 8s/step - loss: -0.5753 - binary_accuracy: 0.9962 - iou: 0.4184 - dice_coef: 0.5749 - val_loss: -0.1741 - val_binary_accuracy: 0.9951 - val_iou: 0.1182 - val_dice_coef: 0.1808
# Epoch 112/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5705 - binary_accuracy: 0.9968 - iou: 0.4115 - dice_coef: 0.5664
# Epoch 112: val_loss did not improve from -0.38044
# 11/11 [==============================] - 94s 9s/step - loss: -0.5705 - binary_accuracy: 0.9968 - iou: 0.4115 - dice_coef: 0.5664 - val_loss: -0.0151 - val_binary_accuracy: 0.9946 - val_iou: 0.0270 - val_dice_coef: 0.0270
# Epoch 113/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5494 - binary_accuracy: 0.9959 - iou: 0.4058 - dice_coef: 0.5523
# Epoch 113: val_loss did not improve from -0.38044
# 11/11 [==============================] - 84s 8s/step - loss: -0.5494 - binary_accuracy: 0.9959 - iou: 0.4058 - dice_coef: 0.5523 - val_loss: -0.0210 - val_binary_accuracy: 0.9948 - val_iou: 0.0444 - val_dice_coef: 0.0444
# Epoch 114/300
# 11/11 [==============================] - ETA: 0s - loss: -0.4765 - binary_accuracy: 0.9952 - iou: 0.3324 - dice_coef: 0.4723
# Epoch 114: val_loss did not improve from -0.38044
# ...
# Epoch 206/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6484 - binary_accuracy: 0.9970 - iou: 0.5103 - dice_coef: 0.6512
# Epoch 206: val_loss did not improve from -0.53999
# 11/11 [==============================] - 85s 8s/step - loss: -0.6484 - binary_accuracy: 0.9970 - iou: 0.5103 - dice_coef: 0.6512 - val_loss: -0.5142 - val_binary_accuracy: 0.9954 - val_iou: 0.3659 - val_dice_coef: 0.5095
# Epoch 207/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6955 - binary_accuracy: 0.9972 - iou: 0.5639 - dice_coef: 0.6974
# Epoch 207: val_loss did not improve from -0.53999
# 11/11 [==============================] - 86s 8s/step - loss: -0.6955 - binary_accuracy: 0.9972 - iou: 0.5639 - dice_coef: 0.6974 - val_loss: -0.4152 - val_binary_accuracy: 0.9898 - val_iou: 0.2432 - val_dice_coef: 0.3770
# Epoch 208/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6915 - binary_accuracy: 0.9974 - iou: 0.5640 - dice_coef: 0.6932
# Epoch 208: val_loss did not improve from -0.53999
# 11/11 [==============================] - 84s 8s/step - loss: -0.6915 - binary_accuracy: 0.9974 - iou: 0.5640 - dice_coef: 0.6932 - val_loss: -0.4892 - val_binary_accuracy: 0.9933 - val_iou: 0.3515 - val_dice_coef: 0.5092
# Epoch 209/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6908 - binary_accuracy: 0.9972 - iou: 0.5594 - dice_coef: 0.6929
# Epoch 209: val_loss did not improve from -0.53999
# 11/11 [==============================] - 84s 8s/step - loss: -0.6908 - binary_accuracy: 0.9972 - iou: 0.5594 - dice_coef: 0.6929 - val_loss: -0.5063 - val_binary_accuracy: 0.9950 - val_iou: 0.4195 - val_dice_coef: 0.5593
# Epoch 210/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6652 - binary_accuracy: 0.9975 - iou: 0.5127 - dice_coef: 0.6565
# Epoch 210: val_loss did not improve from -0.53999
# 11/11 [==============================] - 85s 8s/step - loss: -0.6652 - binary_accuracy: 0.9975 - iou: 0.5127 - dice_coef: 0.6565 - val_loss: -0.4863 - val_binary_accuracy: 0.9946 - val_iou: 0.3951 - val_dice_coef: 0.5444
# Epoch 211/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6223 - binary_accuracy: 0.9965 - iou: 0.4853 - dice_coef: 0.6254
# Epoch 211: val_loss did not improve from -0.53999
# 11/11 [==============================] - 85s 8s/step - loss: -0.6223 - binary_accuracy: 0.9965 - iou: 0.4853 - dice_coef: 0.6254 - val_loss: -0.2688 - val_binary_accuracy: 0.9952 - val_iou: 0.1513 - val_dice_coef: 0.2329
# Epoch 212/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6897 - binary_accuracy: 0.9974 - iou: 0.5639 - dice_coef: 0.6904
# Epoch 212: val_loss did not improve from -0.53999
# 11/11 [==============================] - 86s 8s/step - loss: -0.6897 - binary_accuracy: 0.9974 - iou: 0.5639 - dice_coef: 0.6904 - val_loss: -0.3260 - val_binary_accuracy: 0.9919 - val_iou: 0.1923 - val_dice_coef: 0.3041
# Epoch 213/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6983 - binary_accuracy: 0.9973 - iou: 0.5673 - dice_coef: 0.6961
# Epoch 213: val_loss did not improve from -0.53999
# 11/11 [==============================] - 85s 8s/step - loss: -0.6983 - binary_accuracy: 0.9973 - iou: 0.5673 - dice_coef: 0.6961 - val_loss: -0.3400 - val_binary_accuracy: 0.9862 - val_iou: 0.1962 - val_dice_coef: 0.3179
# Epoch 214/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6820 - binary_accuracy: 0.9975 - iou: 0.5552 - dice_coef: 0.6851
# Epoch 214: val_loss did not improve from -0.53999
# 11/11 [==============================] - 85s 8s/step - loss: -0.6820 - binary_accuracy: 0.9975 - iou: 0.5552 - dice_coef: 0.6851 - val_loss: -0.4429 - val_binary_accuracy: 0.9919 - val_iou: 0.2746 - val_dice_coef: 0.4225
# Epoch 215/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6869 - binary_accuracy: 0.9974 - iou: 0.5413 - dice_coef: 0.6752
# Epoch 215: val_loss did not improve from -0.53999
# 11/11 [==============================] - 85s 8s/step - loss: -0.6869 - binary_accuracy: 0.9974 - iou: 0.5413 - dice_coef: 0.6752 - val_loss: -0.4535 - val_binary_accuracy: 0.9957 - val_iou: 0.3151 - val_dice_coef: 0.4416
# Epoch 216/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6637 - binary_accuracy: 0.9970 - iou: 0.5370 - dice_coef: 0.6590
# Epoch 216: val_loss did not improve from -0.53999
# 11/11 [==============================] - 87s 9s/step - loss: -0.6637 - binary_accuracy: 0.9970 - iou: 0.5370 - dice_coef: 0.6590 - val_loss: -0.4599 - val_binary_accuracy: 0.9962 - val_iou: 0.3430 - val_dice_coef: 0.4552
# Epoch 217/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6655 - binary_accuracy: 0.9972 - iou: 0.5369 - dice_coef: 0.6662
# Epoch 217: val_loss did not improve from -0.53999
# 11/11 [==============================] - 86s 8s/step - loss: -0.6655 - binary_accuracy: 0.9972 - iou: 0.5369 - dice_coef: 0.6662 - val_loss: -0.4936 - val_binary_accuracy: 0.9948 - val_iou: 0.3296 - val_dice_coef: 0.4717
# Epoch 218/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6496 - binary_accuracy: 0.9973 - iou: 0.5260 - dice_coef: 0.6542
# Epoch 218: val_loss did not improve from -0.53999
# 11/11 [==============================] - 87s 9s/step - loss: -0.6496 - binary_accuracy: 0.9973 - iou: 0.5260 - dice_coef: 0.6542 - val_loss: -0.5321 - val_binary_accuracy: 0.9953 - val_iou: 0.3998 - val_dice_coef: 0.5526
# Epoch 219/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7042 - binary_accuracy: 0.9971 - iou: 0.5737 - dice_coef: 0.7069
# Epoch 219: val_loss did not improve from -0.53999
# 11/11 [==============================] - 87s 9s/step - loss: -0.7042 - binary_accuracy: 0.9971 - iou: 0.5737 - dice_coef: 0.7069 - val_loss: -0.5156 - val_binary_accuracy: 0.9961 - val_iou: 0.3331 - val_dice_coef: 0.4545
# Epoch 220/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7181 - binary_accuracy: 0.9975 - iou: 0.5810 - dice_coef: 0.7056
# Epoch 220: val_loss did not improve from -0.53999
# 11/11 [==============================] - 87s 9s/step - loss: -0.7181 - binary_accuracy: 0.9975 - iou: 0.5810 - dice_coef: 0.7056 - val_loss: -0.4979 - val_binary_accuracy: 0.9942 - val_iou: 0.3265 - val_dice_coef: 0.4619
# Epoch 221/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6396 - binary_accuracy: 0.9969 - iou: 0.4983 - dice_coef: 0.6279
# Epoch 221: val_loss did not improve from -0.53999
# 11/11 [==============================] - 87s 9s/step - loss: -0.6396 - binary_accuracy: 0.9969 - iou: 0.4983 - dice_coef: 0.6279 - val_loss: -0.4845 - val_binary_accuracy: 0.9955 - val_iou: 0.2984 - val_dice_coef: 0.4295
# Epoch 222/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6174 - binary_accuracy: 0.9969 - iou: 0.4835 - dice_coef: 0.6185
# Epoch 222: val_loss did not improve from -0.53999
# 11/11 [==============================] - 88s 9s/step - loss: -0.6174 - binary_accuracy: 0.9969 - iou: 0.4835 - dice_coef: 0.6185 - val_loss: -0.4246 - val_binary_accuracy: 0.9908 - val_iou: 0.2891 - val_dice_coef: 0.4328
# Epoch 223/300
# 11/11 [==============================] - ETA: 0s - loss: -0.5885 - binary_accuracy: 0.9955 - iou: 0.4477 - dice_coef: 0.5906
# Epoch 223: val_loss did not improve from -0.53999
# 11/11 [==============================] - 87s 9s/step - loss: -0.5885 - binary_accuracy: 0.9955 - iou: 0.4477 - dice_coef: 0.5906 - val_loss: -0.1691 - val_binary_accuracy: 0.9947 - val_iou: 0.1574 - val_dice_coef: 0.2194
# Epoch 224/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6843 - binary_accuracy: 0.9977 - iou: 0.5508 - dice_coef: 0.6869
# Epoch 224: val_loss did not improve from -0.53999
# 11/11 [==============================] - 86s 8s/step - loss: -0.6843 - binary_accuracy: 0.9977 - iou: 0.5508 - dice_coef: 0.6869 - val_loss: -0.3563 - val_binary_accuracy: 0.9952 - val_iou: 0.2490 - val_dice_coef: 0.3494
# Epoch 225/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7300 - binary_accuracy: 0.9977 - iou: 0.5964 - dice_coef: 0.7181
# Epoch 225: val_loss improved from -0.53999 to -0.55383, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 89s 9s/step - loss: -0.7300 - binary_accuracy: 0.9977 - iou: 0.5964 - dice_coef: 0.7181 - val_loss: -0.5538 - val_binary_accuracy: 0.9960 - val_iou: 0.4879 - val_dice_coef: 0.6362
# Epoch 226/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6821 - binary_accuracy: 0.9972 - iou: 0.5481 - dice_coef: 0.6829
# Epoch 226: val_loss improved from -0.55383 to -0.55864, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 99s 10s/step - loss: -0.6821 - binary_accuracy: 0.9972 - iou: 0.5481 - dice_coef: 0.6829 - val_loss: -0.5586 - val_binary_accuracy: 0.9964 - val_iou: 0.3628 - val_dice_coef: 0.5046
# Epoch 227/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6925 - binary_accuracy: 0.9972 - iou: 0.5675 - dice_coef: 0.6918
# Epoch 227: val_loss did not improve from -0.55864
# 11/11 [==============================] - 87s 9s/step - loss: -0.6925 - binary_accuracy: 0.9972 - iou: 0.5675 - dice_coef: 0.6918 - val_loss: -0.5048 - val_binary_accuracy: 0.9961 - val_iou: 0.4198 - val_dice_coef: 0.5620
# Epoch 228/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6750 - binary_accuracy: 0.9972 - iou: 0.5483 - dice_coef: 0.6786
# Epoch 228: val_loss did not improve from -0.55864
# 11/11 [==============================] - 86s 8s/step - loss: -0.6750 - binary_accuracy: 0.9972 - iou: 0.5483 - dice_coef: 0.6786 - val_loss: -0.4879 - val_binary_accuracy: 0.9942 - val_iou: 0.3068 - val_dice_coef: 0.4535
# Epoch 229/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7003 - binary_accuracy: 0.9974 - iou: 0.5859 - dice_coef: 0.7066
# Epoch 229: val_loss did not improve from -0.55864
# 11/11 [==============================] - 85s 8s/step - loss: -0.7003 - binary_accuracy: 0.9974 - iou: 0.5859 - dice_coef: 0.7066 - val_loss: -0.5315 - val_binary_accuracy: 0.9955 - val_iou: 0.3793 - val_dice_coef: 0.5141
# Epoch 230/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7198 - binary_accuracy: 0.9976 - iou: 0.5835 - dice_coef: 0.7092
# Epoch 230: val_loss did not improve from -0.55864
# 11/11 [==============================] - 84s 8s/step - loss: -0.7198 - binary_accuracy: 0.9976 - iou: 0.5835 - dice_coef: 0.7092 - val_loss: -0.4856 - val_binary_accuracy: 0.9949 - val_iou: 0.3262 - val_dice_coef: 0.4521
# Epoch 231/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6350 - binary_accuracy: 0.9972 - iou: 0.5024 - dice_coef: 0.6295
# Epoch 231: val_loss did not improve from -0.55864
# 11/11 [==============================] - 84s 8s/step - loss: -0.6350 - binary_accuracy: 0.9972 - iou: 0.5024 - dice_coef: 0.6295 - val_loss: -0.5343 - val_binary_accuracy: 0.9963 - val_iou: 0.4217 - val_dice_coef: 0.5755
# Epoch 232/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7094 - binary_accuracy: 0.9976 - iou: 0.5898 - dice_coef: 0.7129
# Epoch 232: val_loss did not improve from -0.55864
# 11/11 [==============================] - 85s 8s/step - loss: -0.7094 - binary_accuracy: 0.9976 - iou: 0.5898 - dice_coef: 0.7129 - val_loss: -0.5029 - val_binary_accuracy: 0.9954 - val_iou: 0.3516 - val_dice_coef: 0.4719
# Epoch 233/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6972 - binary_accuracy: 0.9974 - iou: 0.5551 - dice_coef: 0.7000
# Epoch 233: val_loss did not improve from -0.55864
# 11/11 [==============================] - 87s 9s/step - loss: -0.6972 - binary_accuracy: 0.9974 - iou: 0.5551 - dice_coef: 0.7000 - val_loss: -0.4844 - val_binary_accuracy: 0.9954 - val_iou: 0.3082 - val_dice_coef: 0.4301
# Epoch 234/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6939 - binary_accuracy: 0.9974 - iou: 0.5665 - dice_coef: 0.6904
# Epoch 234: val_loss did not improve from -0.55864
# 11/11 [==============================] - 85s 8s/step - loss: -0.6939 - binary_accuracy: 0.9974 - iou: 0.5665 - dice_coef: 0.6904 - val_loss: -0.4409 - val_binary_accuracy: 0.9928 - val_iou: 0.2947 - val_dice_coef: 0.4297
# Epoch 235/300
# 11/11 [==============================] - ETA: 0s - loss: -0.6563 - binary_accuracy: 0.9969 - iou: 0.5108 - dice_coef: 0.6464
# Epoch 235: val_loss did not improve from -0.55864
# 11/11 [==============================] - 86s 9s/step - loss: -0.6563 - binary_accuracy: 0.9969 - iou: 0.5108 - dice_coef: 0.6464 - val_loss: -0.5000 - val_binary_accuracy: 0.9958 - val_iou: 0.3774 - val_dice_coef: 0.5258
# Epoch 236/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7060 - binary_accuracy: 0.9976 - iou: 0.5919 - dice_coef: 0.7116
# Epoch 236: val_loss did not improve from -0.55864
# 11/11 [==============================] - 87s 9s/step - loss: -0.7060 - binary_accuracy: 0.9976 - iou: 0.5919 - dice_coef: 0.7116 - val_loss: -0.5280 - val_binary_accuracy: 0.9961 - val_iou: 0.3182 - val_dice_coef: 0.4484
# Epoch 237/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7155 - binary_accuracy: 0.9978 - iou: 0.5959 - dice_coef: 0.7161
# Epoch 237: val_loss improved from -0.55864 to -0.56904, saving model to /content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5
# 11/11 [==============================] - 91s 9s/step - loss: -0.7155 - binary_accuracy: 0.9978 - iou: 0.5959 - dice_coef: 0.7161 - val_loss: -0.5690 - val_binary_accuracy: 0.9957 - val_iou: 0.3993 - val_dice_coef: 0.5526
# Epoch 238/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7192 - binary_accuracy: 0.9977 - iou: 0.6027 - dice_coef: 0.7228
# Epoch 238: val_loss did not improve from -0.56904
# 11/11 [==============================] - 86s 8s/step - loss: -0.7192 - binary_accuracy: 0.9977 - iou: 0.6027 - dice_coef: 0.7228 - val_loss: -0.5176 - val_binary_accuracy: 0.9962 - val_iou: 0.3589 - val_dice_coef: 0.4828
# Epoch 239/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7345 - binary_accuracy: 0.9975 - iou: 0.6207 - dice_coef: 0.7379
# Epoch 239: val_loss did not improve from -0.56904
# 11/11 [==============================] - 86s 8s/step - loss: -0.7345 - binary_accuracy: 0.9975 - iou: 0.6207 - dice_coef: 0.7379 - val_loss: -0.4908 - val_binary_accuracy: 0.9950 - val_iou: 0.3076 - val_dice_coef: 0.4391
# Epoch 240/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7135 - binary_accuracy: 0.9976 - iou: 0.5827 - dice_coef: 0.7057
# Epoch 240: val_loss did not improve from -0.56904
# 11/11 [==============================] - 85s 8s/step - loss: -0.7135 - binary_accuracy: 0.9976 - iou: 0.5827 - dice_coef: 0.7057 - val_loss: -0.4202 - val_binary_accuracy: 0.9940 - val_iou: 0.2699 - val_dice_coef: 0.3733
# Epoch 241/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7338 - binary_accuracy: 0.9976 - iou: 0.6212 - dice_coef: 0.7363
# Epoch 241: val_loss did not improve from -0.56904
# 11/11 [==============================] - 85s 8s/step - loss: -0.7338 - binary_accuracy: 0.9976 - iou: 0.6212 - dice_coef: 0.7363 - val_loss: -0.5109 - val_binary_accuracy: 0.9954 - val_iou: 0.3469 - val_dice_coef: 0.4860
# Epoch 242/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7360 - binary_accuracy: 0.9976 - iou: 0.6166 - dice_coef: 0.7377
# Epoch 242: val_loss did not improve from -0.56904
# 11/11 [==============================] - 85s 8s/step - loss: -0.7360 - binary_accuracy: 0.9976 - iou: 0.6166 - dice_coef: 0.7377 - val_loss: -0.4896 - val_binary_accuracy: 0.9952 - val_iou: 0.3249 - val_dice_coef: 0.4549
# Epoch 243/300
# 11/11 [==============================] - ETA: 0s - loss: -0.7148 - binary_accuracy: 0.9973 - iou: 0.5967 - dice_coef: 0.7155
# Epoch 243: val_loss did not improve from -0.56904
# 11/11 [==============================] - 87s 9s/step - loss: -0.7148 - binary_accuracy: 0.9973 - iou: 0.5967 - dice_coef: 0.7155 - val_loss: -0.4887 - val_binary_accuracy: 0.9962 - val_iou: 0.3651 - val_dice_coef: 0.4847
# Epoch 244/300

# %%
model = load_model('/content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5',
                   custom_objects={'dice_coef_loss': dice_coef_loss, 'iou': iou, 'dice_coef': dice_coef})

# %%
a = history.history

list_traindice = a['dice_coef']
list_testdice = a['val_dice_coef']

list_trainjaccard = a['iou']
list_testjaccard = a['val_iou']

list_trainloss = a['loss']
list_testloss = a['val_loss']

plt.figure(1)
plt.plot(list_testloss, 'b-')
plt.plot(list_trainloss,'r-')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('loss graph', fontsize = 15)
plt.figure(2)
plt.plot(list_traindice, 'r-')
plt.plot(list_testdice, 'b-')
plt.xlabel('iteration')
plt.ylabel('accuracy')
plt.title('accuracy graph', fontsize = 15)
plt.show()

# %%
1077 // 32
# Out:
# 33

# %%
model = load_model('/content/drive/MyDrive/ModelCheckpoint/unet_segmentation.hdf5',
                   custom_objects={'dice_coef_loss': dice_coef_loss, 'iou': iou, 'dice_coef': dice_coef})

# %%
test_gen = train_generator(df_test, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
results = model.evaluate(test_gen, steps=10)
print("Test lost: ",results[0])
print("Test IOU: ",results[1])
print("Test Dice Coefficent: ",results[2])

# %%
im_height,im_width=256,256
for i in range(22):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['filename'].iloc[index])
    img = cv2.resize(img ,(im_height, im_width))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    mask = np.squeeze(cv2.imread(df_test['mask'].iloc[index]))
    mask = cv2.resize(mask ,(im_height, im_width))
    plt.imshow(mask)
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5,cmap='gray')
    plt.title('Prediction')
    plt.show()

# %%
for i in range(22):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['filename'].iloc[i])
    img = cv2.resize(img ,(im_height, im_width))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    mask = np.squeeze(cv2.imread(df_test['mask'].iloc[i]))
    mask = cv2.resize(mask ,(im_height, im_width))
    plt.imshow(mask)
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5,cmap='gray')
    plt.title('Prediction')
    plt.show()
